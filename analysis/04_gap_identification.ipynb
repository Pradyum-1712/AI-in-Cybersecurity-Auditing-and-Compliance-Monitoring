# %% [markdown]
# # Research Gap Identification
# Find underrepresented areas and future research directions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
# Load data
categorization = pd.read_csv('../data/categorization.csv')
timeline = pd.read_csv('../data/timeline_analysis.csv')

# %%
# Identify underrepresented themes
theme_distribution = categorization['theme'].value_counts()
underrepresented = theme_distribution[theme_distribution < theme_distribution.median()]

print("Underrepresented Research Areas:")
print(underrepresented)

# %%
# Keyword frequency analysis
# TODO: Implement keyword extraction and frequency analysis

# %% [markdown]
# ## Research Gaps Summary
# - List identified gaps
# - Future research directions
# - Recommendations
