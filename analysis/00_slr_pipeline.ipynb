# %% [markdown]
# # Systematic Literature Review Pipeline
# Master notebook orchestrating the full SLR analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Load Data

# %%
# Load all data files
papers_metadata = pd.read_csv('../data/papers_metadata.csv')
comparison_metrics = pd.read_csv('../data/comparison_metrics.csv')
categorization = pd.read_csv('../data/categorization.csv')
timeline_analysis = pd.read_csv('../data/timeline_analysis.csv')

print(f"Total papers: {len(papers_metadata)}")

# %% [markdown]
# ## 2. Run Sub-Analyses
# Execute other notebooks for detailed analysis

# %%
# Import analysis modules
# %run 01_paper_categorization.ipynb
# %run 02_performance_comparison.ipynb
# %run 03_trend_analysis.ipynb
# %run 04_gap_identification.ipynb

# %% [markdown]
# ## 3. Generate Summary Statistics

# %%
# Summary statistics
summary = {
    'total_papers': len(papers_metadata),
    'year_range': f"{papers_metadata['year'].min()}-{papers_metadata['year'].max()}",
    'publishers': papers_metadata['publisher'].value_counts().to_dict()
}

print(json.dumps(summary, indent=2))
